# %% [markdown]
# # Multi-Layer Fully Connected Network
# In this exercise, you will implement a fully connected network with an arbitrary number of hidden layers.

# %% [markdown]
# Read through the `FullyConnectedNet` class in the file `cs231n/classifiers/fc_net.py`.
#
# Implement the network initialization, forward pass, and backward pass. Throughout this assignment, you will be implementing layers in `cs231n/layers.py`. You can re-use your implementations for `affine_forward`, `affine_backward`, `relu_forward`, `relu_backward`, and `softmax_loss` from before. For right now, don't worry about implementing dropout or batch/layer normalization yet, as you will add those features later.

# %%
# Setup cell.
import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # Set default size of plots.
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gray"

#%load_ext autoreload
#%autoreload 2

def rel_error(x, y):
    """Returns relative error."""
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR-10 data.
data = get_CIFAR10_data()
for k, v in list(data.items()):
    print(f"{k}: {v.shape}")
# Out:
# C:\Users\wrx\assignment1\cs231n\data_utils.py:16: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   return pickle.load(f, encoding="latin1")
# X_train: (49000, 3, 32, 32)
# y_train: (49000,)
# X_val: (1000, 3, 32, 32)
# y_val: (1000,)
# X_test: (1000, 3, 32, 32)
# y_test: (1000,)

# %% [markdown]
# ## Initial Loss and Gradient Check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. This is a good way to see if the initial losses seem reasonable.
#
# For gradient checking, you should expect to see errors around 1e-7 or less.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
    print("Running check with reg = ", reg)
    model = FullyConnectedNet(
        [H1, H2],
        input_dim=D,
        num_classes=C,
        reg=reg,
        weight_scale=5e-2,
        dtype=np.float64
    )

    loss, grads = model.loss(X, y)
    print("Initial loss: ", loss)

    # Most of the errors should be on the order of e-7 or smaller.
    # NOTE: It is fine however to see an error for W2 on the order of e-5
    # for the check when reg = 0.0
    for name in sorted(grads):
        f = lambda _: model.loss(X, y)[0]
        grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
        print(f"{name} relative error: {rel_error(grad_num, grads[name])}")
# Out:
# Running check with reg =  0
# Initial loss:  2.3004790897684924
# W1 relative error: 1.4839894098713283e-07
# W2 relative error: 2.21204793107852e-05
# W3 relative error: 3.527252851540647e-07
# b1 relative error: 5.376386228531692e-09
# b2 relative error: 2.085654200257447e-09
# b3 relative error: 5.7957243458479405e-11
# Running check with reg =  3.14
# Initial loss:  7.052114776533016
# W1 relative error: 3.904541941902138e-09
# W2 relative error: 6.86942277940646e-08
# W3 relative error: 2.131129848945024e-08
# b1 relative error: 1.4752427965311745e-08
# b2 relative error: 1.7223751746766738e-09
# b3 relative error: 1.5702714832602802e-10

# %% [markdown]
# As another sanity check, make sure your network can overfit on a small dataset of 50 images. First, we will try a three-layer network with 100 units in each hidden layer. In the following cell, tweak the **learning rate** and **weight initialization scale** to overfit and achieve 100% training accuracy within 20 epochs.

# %% [markdown]
# # 调参原则：固定一个调另一个

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  "X_train": data["X_train"][:num_train],
  "y_train": data["y_train"][:num_train],
  "X_val": data["X_val"],
  "y_val": data["y_val"],
}

weight_scale = 1e-2   # Experiment with this!
learning_rate = 1e-2  # Experiment with this!


model = FullyConnectedNet(
    [100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=20,
    batch_size=25,
    update_rule="sgd",
    optim_config={"learning_rate": learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title("Training loss history")
plt.xlabel("Iteration")
plt.ylabel("Training loss")
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# (Iteration 1 / 40) loss: 2.363364
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.108000
# (Epoch 1 / 20) train acc: 0.320000; val_acc: 0.127000
# (Epoch 2 / 20) train acc: 0.440000; val_acc: 0.172000
# (Epoch 3 / 20) train acc: 0.500000; val_acc: 0.184000
# (Epoch 4 / 20) train acc: 0.540000; val_acc: 0.181000
# (Epoch 5 / 20) train acc: 0.740000; val_acc: 0.190000
# (Iteration 11 / 40) loss: 0.839976
# (Epoch 6 / 20) train acc: 0.740000; val_acc: 0.187000
# (Epoch 7 / 20) train acc: 0.740000; val_acc: 0.183000
# (Epoch 8 / 20) train acc: 0.820000; val_acc: 0.177000
# (Epoch 9 / 20) train acc: 0.860000; val_acc: 0.200000
# (Epoch 10 / 20) train acc: 0.920000; val_acc: 0.191000
# (Iteration 21 / 40) loss: 0.337174
# (Epoch 11 / 20) train acc: 0.960000; val_acc: 0.189000
# (Epoch 12 / 20) train acc: 0.940000; val_acc: 0.180000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.199000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.199000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.195000
# (Iteration 31 / 40) loss: 0.075911
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.182000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.201000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.207000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.185000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.192000

# %% [markdown]
# Now, try to use a five-layer network with 100 units on each layer to overfit on 50 training examples. Again, you will have to adjust the learning rate and weight initialization scale, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples by
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

learning_rate = 5e-2  # Experiment with this!
weight_scale = 2e-2   # Experiment with this!


model = FullyConnectedNet(
    [100, 100, 100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=150,
    batch_size=25,
    update_rule='sgd',
    optim_config={'learning_rate': learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# (Iteration 1 / 300) loss: 2.306548
# (Epoch 0 / 150) train acc: 0.160000; val_acc: 0.112000
# (Epoch 1 / 150) train acc: 0.260000; val_acc: 0.103000
# (Epoch 2 / 150) train acc: 0.240000; val_acc: 0.096000
# (Epoch 3 / 150) train acc: 0.380000; val_acc: 0.111000
# (Epoch 4 / 150) train acc: 0.300000; val_acc: 0.101000
# (Epoch 5 / 150) train acc: 0.340000; val_acc: 0.092000
# (Iteration 11 / 300) loss: 2.150273
# (Epoch 6 / 150) train acc: 0.260000; val_acc: 0.100000
# (Epoch 7 / 150) train acc: 0.180000; val_acc: 0.080000
# (Epoch 8 / 150) train acc: 0.280000; val_acc: 0.100000
# (Epoch 9 / 150) train acc: 0.520000; val_acc: 0.166000
# (Epoch 10 / 150) train acc: 0.340000; val_acc: 0.145000
# (Iteration 21 / 300) loss: 2.236564
# (Epoch 11 / 150) train acc: 0.360000; val_acc: 0.141000
# (Epoch 12 / 150) train acc: 0.500000; val_acc: 0.161000
# (Epoch 13 / 150) train acc: 0.500000; val_acc: 0.125000
# (Epoch 14 / 150) train acc: 0.580000; val_acc: 0.155000
# (Epoch 15 / 150) train acc: 0.580000; val_acc: 0.148000
# (Iteration 31 / 300) loss: 1.142736
# (Epoch 16 / 150) train acc: 0.620000; val_acc: 0.181000
# (Epoch 17 / 150) train acc: 0.520000; val_acc: 0.162000
# (Epoch 18 / 150) train acc: 0.580000; val_acc: 0.166000
# (Epoch 19 / 150) train acc: 0.660000; val_acc: 0.153000
# (Epoch 20 / 150) train acc: 0.420000; val_acc: 0.131000
# (Iteration 41 / 300) loss: 1.668583
# (Epoch 21 / 150) train acc: 0.660000; val_acc: 0.169000
# (Epoch 22 / 150) train acc: 0.800000; val_acc: 0.191000
# (Epoch 23 / 150) train acc: 0.840000; val_acc: 0.188000
# (Epoch 24 / 150) train acc: 0.760000; val_acc: 0.189000
# (Epoch 25 / 150) train acc: 0.580000; val_acc: 0.153000
# (Iteration 51 / 300) loss: 0.967269
# (Epoch 26 / 150) train acc: 0.800000; val_acc: 0.194000
# (Epoch 27 / 150) train acc: 0.820000; val_acc: 0.192000
# (Epoch 28 / 150) train acc: 0.860000; val_acc: 0.216000
# (Epoch 29 / 150) train acc: 0.860000; val_acc: 0.213000
# (Epoch 30 / 150) train acc: 0.900000; val_acc: 0.198000
# (Iteration 61 / 300) loss: 0.177662
# (Epoch 31 / 150) train acc: 0.880000; val_acc: 0.209000
# (Epoch 32 / 150) train acc: 0.920000; val_acc: 0.210000
# (Epoch 33 / 150) train acc: 0.940000; val_acc: 0.200000
# (Epoch 34 / 150) train acc: 0.940000; val_acc: 0.202000
# (Epoch 35 / 150) train acc: 0.940000; val_acc: 0.213000
# (Iteration 71 / 300) loss: 0.188694
# (Epoch 36 / 150) train acc: 0.940000; val_acc: 0.206000
# (Epoch 37 / 150) train acc: 0.940000; val_acc: 0.203000
# (Epoch 38 / 150) train acc: 0.900000; val_acc: 0.203000
# (Epoch 39 / 150) train acc: 0.500000; val_acc: 0.150000
# (Epoch 40 / 150) train acc: 0.080000; val_acc: 0.087000
# (Iteration 81 / 300) loss: 60.456515
# (Epoch 41 / 150) train acc: 0.160000; val_acc: 0.079000
# (Epoch 42 / 150) train acc: 0.200000; val_acc: 0.086000
# (Epoch 43 / 150) train acc: 0.160000; val_acc: 0.112000
# (Epoch 44 / 150) train acc: 0.200000; val_acc: 0.133000
# (Epoch 45 / 150) train acc: 0.220000; val_acc: 0.098000
# (Iteration 91 / 300) loss: 2.433287
# (Epoch 46 / 150) train acc: 0.140000; val_acc: 0.103000
# (Epoch 47 / 150) train acc: 0.200000; val_acc: 0.098000
# (Epoch 48 / 150) train acc: 0.200000; val_acc: 0.126000
# (Epoch 49 / 150) train acc: 0.180000; val_acc: 0.127000
# (Epoch 50 / 150) train acc: 0.180000; val_acc: 0.100000
# (Iteration 101 / 300) loss: 2.169590
# (Epoch 51 / 150) train acc: 0.240000; val_acc: 0.093000
# (Epoch 52 / 150) train acc: 0.220000; val_acc: 0.121000
# (Epoch 53 / 150) train acc: 0.200000; val_acc: 0.089000
# (Epoch 54 / 150) train acc: 0.240000; val_acc: 0.108000
# (Epoch 55 / 150) train acc: 0.300000; val_acc: 0.137000
# (Iteration 111 / 300) loss: 1.903199
# (Epoch 56 / 150) train acc: 0.240000; val_acc: 0.127000
# (Epoch 57 / 150) train acc: 0.320000; val_acc: 0.106000
# (Epoch 58 / 150) train acc: 0.200000; val_acc: 0.085000
# (Epoch 59 / 150) train acc: 0.180000; val_acc: 0.087000
# (Epoch 60 / 150) train acc: 0.320000; val_acc: 0.089000
# (Iteration 121 / 300) loss: 1.815569
# (Epoch 61 / 150) train acc: 0.340000; val_acc: 0.112000
# (Epoch 62 / 150) train acc: 0.400000; val_acc: 0.145000
# (Epoch 63 / 150) train acc: 0.420000; val_acc: 0.148000
# (Epoch 64 / 150) train acc: 0.300000; val_acc: 0.146000
# (Epoch 65 / 150) train acc: 0.400000; val_acc: 0.101000
# (Iteration 131 / 300) loss: 1.659695
# (Epoch 66 / 150) train acc: 0.220000; val_acc: 0.104000
# (Epoch 67 / 150) train acc: 0.340000; val_acc: 0.099000
# (Epoch 68 / 150) train acc: 0.580000; val_acc: 0.123000
# (Epoch 69 / 150) train acc: 0.520000; val_acc: 0.123000
# (Epoch 70 / 150) train acc: 0.400000; val_acc: 0.107000
# (Iteration 141 / 300) loss: 1.803189
# (Epoch 71 / 150) train acc: 0.380000; val_acc: 0.109000
# (Epoch 72 / 150) train acc: 0.460000; val_acc: 0.103000
# (Epoch 73 / 150) train acc: 0.400000; val_acc: 0.123000
# (Epoch 74 / 150) train acc: 0.420000; val_acc: 0.124000
# (Epoch 75 / 150) train acc: 0.320000; val_acc: 0.091000
# (Iteration 151 / 300) loss: 3.360854
# (Epoch 76 / 150) train acc: 0.260000; val_acc: 0.113000
# (Epoch 77 / 150) train acc: 0.380000; val_acc: 0.126000
# (Epoch 78 / 150) train acc: 0.360000; val_acc: 0.113000
# (Epoch 79 / 150) train acc: 0.480000; val_acc: 0.135000
# (Epoch 80 / 150) train acc: 0.540000; val_acc: 0.142000
# (Iteration 161 / 300) loss: 1.484593
# (Epoch 81 / 150) train acc: 0.380000; val_acc: 0.146000
# (Epoch 82 / 150) train acc: 0.360000; val_acc: 0.111000
# (Epoch 83 / 150) train acc: 0.400000; val_acc: 0.111000
# (Epoch 84 / 150) train acc: 0.520000; val_acc: 0.131000
# (Epoch 85 / 150) train acc: 0.540000; val_acc: 0.118000
# (Iteration 171 / 300) loss: 1.675732
# (Epoch 86 / 150) train acc: 0.560000; val_acc: 0.128000
# (Epoch 87 / 150) train acc: 0.580000; val_acc: 0.118000
# (Epoch 88 / 150) train acc: 0.440000; val_acc: 0.132000
# (Epoch 89 / 150) train acc: 0.600000; val_acc: 0.134000
# (Epoch 90 / 150) train acc: 0.680000; val_acc: 0.142000
# (Iteration 181 / 300) loss: 0.762653
# (Epoch 91 / 150) train acc: 0.600000; val_acc: 0.141000
# (Epoch 92 / 150) train acc: 0.620000; val_acc: 0.142000
# (Epoch 93 / 150) train acc: 0.580000; val_acc: 0.140000
# (Epoch 94 / 150) train acc: 0.400000; val_acc: 0.140000
# (Epoch 95 / 150) train acc: 0.160000; val_acc: 0.108000
# (Iteration 191 / 300) loss: 2.304122
# (Epoch 96 / 150) train acc: 0.140000; val_acc: 0.126000
# (Epoch 97 / 150) train acc: 0.200000; val_acc: 0.115000
# (Epoch 98 / 150) train acc: 0.380000; val_acc: 0.133000
# (Epoch 99 / 150) train acc: 0.460000; val_acc: 0.129000
# (Epoch 100 / 150) train acc: 0.500000; val_acc: 0.143000
# (Iteration 201 / 300) loss: 1.332755
# (Epoch 101 / 150) train acc: 0.480000; val_acc: 0.147000
# (Epoch 102 / 150) train acc: 0.460000; val_acc: 0.139000
# (Epoch 103 / 150) train acc: 0.500000; val_acc: 0.140000
# (Epoch 104 / 150) train acc: 0.540000; val_acc: 0.153000
# (Epoch 105 / 150) train acc: 0.500000; val_acc: 0.131000
# (Iteration 211 / 300) loss: 1.391546
# (Epoch 106 / 150) train acc: 0.500000; val_acc: 0.145000
# (Epoch 107 / 150) train acc: 0.560000; val_acc: 0.133000
# (Epoch 108 / 150) train acc: 0.660000; val_acc: 0.154000
# (Epoch 109 / 150) train acc: 0.580000; val_acc: 0.123000
# (Epoch 110 / 150) train acc: 0.680000; val_acc: 0.156000
# (Iteration 221 / 300) loss: 0.931115
# (Epoch 111 / 150) train acc: 0.680000; val_acc: 0.142000
# (Epoch 112 / 150) train acc: 0.680000; val_acc: 0.143000
# (Epoch 113 / 150) train acc: 0.680000; val_acc: 0.153000
# (Epoch 114 / 150) train acc: 0.700000; val_acc: 0.159000
# (Epoch 115 / 150) train acc: 0.680000; val_acc: 0.138000
# (Iteration 231 / 300) loss: 0.543388
# (Epoch 116 / 150) train acc: 0.700000; val_acc: 0.165000
# (Epoch 117 / 150) train acc: 0.720000; val_acc: 0.168000
# (Epoch 118 / 150) train acc: 0.740000; val_acc: 0.159000
# (Epoch 119 / 150) train acc: 0.740000; val_acc: 0.158000
# (Epoch 120 / 150) train acc: 0.680000; val_acc: 0.150000
# (Iteration 241 / 300) loss: 0.963007
# (Epoch 121 / 150) train acc: 0.720000; val_acc: 0.165000
# (Epoch 122 / 150) train acc: 0.700000; val_acc: 0.143000
# (Epoch 123 / 150) train acc: 0.700000; val_acc: 0.170000
# (Epoch 124 / 150) train acc: 0.740000; val_acc: 0.159000
# (Epoch 125 / 150) train acc: 0.760000; val_acc: 0.176000
# (Iteration 251 / 300) loss: 0.699938
# (Epoch 126 / 150) train acc: 0.840000; val_acc: 0.171000
# (Epoch 127 / 150) train acc: 0.840000; val_acc: 0.173000
# (Epoch 128 / 150) train acc: 0.860000; val_acc: 0.170000
# (Epoch 129 / 150) train acc: 0.860000; val_acc: 0.172000
# (Epoch 130 / 150) train acc: 0.860000; val_acc: 0.170000
# (Iteration 261 / 300) loss: 0.485081
# (Epoch 131 / 150) train acc: 0.860000; val_acc: 0.167000
# (Epoch 132 / 150) train acc: 0.880000; val_acc: 0.171000
# (Epoch 133 / 150) train acc: 0.880000; val_acc: 0.159000
# (Epoch 134 / 150) train acc: 0.920000; val_acc: 0.162000
# (Epoch 135 / 150) train acc: 0.880000; val_acc: 0.157000
# (Iteration 271 / 300) loss: 0.535667
# (Epoch 136 / 150) train acc: 0.840000; val_acc: 0.163000
# (Epoch 137 / 150) train acc: 0.880000; val_acc: 0.175000
# (Epoch 138 / 150) train acc: 0.800000; val_acc: 0.147000
# (Epoch 139 / 150) train acc: 0.880000; val_acc: 0.156000
# (Epoch 140 / 150) train acc: 0.800000; val_acc: 0.154000
# (Iteration 281 / 300) loss: 0.285060
# (Epoch 141 / 150) train acc: 0.880000; val_acc: 0.170000
# (Epoch 142 / 150) train acc: 0.920000; val_acc: 0.164000
# (Epoch 143 / 150) train acc: 0.920000; val_acc: 0.169000
# (Epoch 144 / 150) train acc: 0.900000; val_acc: 0.162000
# (Epoch 145 / 150) train acc: 0.920000; val_acc: 0.162000
# (Iteration 291 / 300) loss: 0.225723
# (Epoch 146 / 150) train acc: 0.900000; val_acc: 0.163000
# (Epoch 147 / 150) train acc: 0.920000; val_acc: 0.164000
# (Epoch 148 / 150) train acc: 0.920000; val_acc: 0.166000
# (Epoch 149 / 150) train acc: 0.920000; val_acc: 0.158000
# (Epoch 150 / 150) train acc: 0.920000; val_acc: 0.158000

# %% [markdown]
# ## Inline Question 1:
# Did you notice anything about the comparative difficulty of training the three-layer network vs. training the five-layer network? In particular, based on your experience, which network seemed more sensitive to the initialization scale? Why do you think that is the case?
#
# ## Answer:
# [FILL THIS IN]
# ### 三层网络：更容易训练，参数容忍度更高，更容易快速 overfit 小数据集。五层网络：更难训练，对初始化尺度更敏感，更容易出现“卡在随机损失附近”或训练波动，需要更仔细调参和更多迭代。

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# ## SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent. See the Momentum Update section at http://cs231n.github.io/neural-networks-3/#sgd for more information.
#
# Open the file `cs231n/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than e-8.

# %%
from cs231n.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {"learning_rate": 1e-3, "velocity": v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print("next_w error: ", rel_error(next_w, expected_next_w))
print("velocity error: ", rel_error(expected_velocity, config["velocity"]))
# Out:
# next_w error:  8.882347033505819e-09
# velocity error:  4.269287743278663e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )

    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': 5e-3},
        verbose=True,
    )
    solvers[update_rule] = solver
    solver.train()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"loss_{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"train_acc_{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"val_acc_{update_rule}")

for ax in axes:
    ax.legend(loc="best", ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  sgd
# (Iteration 1 / 200) loss: 2.669216
# (Epoch 0 / 5) train acc: 0.111000; val_acc: 0.106000
# (Iteration 11 / 200) loss: 2.268664
# (Iteration 21 / 200) loss: 2.182280
# (Iteration 31 / 200) loss: 2.129847
# (Epoch 1 / 5) train acc: 0.247000; val_acc: 0.234000
# (Iteration 41 / 200) loss: 2.167443
# (Iteration 51 / 200) loss: 2.126374
# (Iteration 61 / 200) loss: 2.102686
# (Iteration 71 / 200) loss: 2.057327
# (Epoch 2 / 5) train acc: 0.281000; val_acc: 0.260000
# (Iteration 81 / 200) loss: 2.132248
# (Iteration 91 / 200) loss: 1.997218
# (Iteration 101 / 200) loss: 1.935045
# (Iteration 111 / 200) loss: 1.923671
# (Epoch 3 / 5) train acc: 0.314000; val_acc: 0.273000
# (Iteration 121 / 200) loss: 1.931602
# (Iteration 131 / 200) loss: 1.822594
# (Iteration 141 / 200) loss: 1.922956
# (Iteration 151 / 200) loss: 1.956077
# (Epoch 4 / 5) train acc: 0.327000; val_acc: 0.306000
# (Iteration 161 / 200) loss: 1.771015
# (Iteration 171 / 200) loss: 2.007430
# (Iteration 181 / 200) loss: 1.818362
# (Iteration 191 / 200) loss: 1.759668
# (Epoch 5 / 5) train acc: 0.382000; val_acc: 0.327000
# Running with  sgd_momentum
# (Iteration 1 / 200) loss: 3.093268
# (Epoch 0 / 5) train acc: 0.131000; val_acc: 0.138000
# (Iteration 11 / 200) loss: 2.231236
# (Iteration 21 / 200) loss: 2.018671
# (Iteration 31 / 200) loss: 1.775577
# (Epoch 1 / 5) train acc: 0.326000; val_acc: 0.283000
# (Iteration 41 / 200) loss: 1.964719
# (Iteration 51 / 200) loss: 1.736066
# (Iteration 61 / 200) loss: 1.748368
# (Iteration 71 / 200) loss: 1.759320
# (Epoch 2 / 5) train acc: 0.404000; val_acc: 0.322000
# (Iteration 81 / 200) loss: 1.776069
# (Iteration 91 / 200) loss: 1.546927
# (Iteration 101 / 200) loss: 1.789270
# (Iteration 111 / 200) loss: 1.717540
# (Epoch 3 / 5) train acc: 0.454000; val_acc: 0.339000
# (Iteration 121 / 200) loss: 1.557764
# (Iteration 131 / 200) loss: 1.372480
# (Iteration 141 / 200) loss: 1.269759
# (Iteration 151 / 200) loss: 1.399547
# (Epoch 4 / 5) train acc: 0.491000; val_acc: 0.337000
# (Iteration 161 / 200) loss: 1.653070
# (Iteration 171 / 200) loss: 1.393330
# (Iteration 181 / 200) loss: 1.423821
# (Iteration 191 / 200) loss: 1.344918
# (Epoch 5 / 5) train acc: 0.546000; val_acc: 0.392000

# %% [markdown]
# ## RMSProp and Adam
# RMSProp [1] and Adam [2] are update rules that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# In the file `cs231n/optim.py`, implement the RMSProp update rule in the `rmsprop` function and implement the Adam update rule in the `adam` function, and check your implementations using the tests below.
#
# **NOTE:** Please implement the _complete_ Adam update rule (with the bias correction mechanism), not the first simplified version mentioned in the course notes.
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation
from cs231n.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('cache error: ', rel_error(expected_cache, config['cache']))
# Out:
# next_w error:  9.524687511038133e-08
# cache error:  2.6477955807156126e-09

# %%
# Test Adam implementation
from cs231n.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('v error: ', rel_error(expected_v, config['v']))
print('m error: ', rel_error(expected_m, config['m']))
# Out:
# next_w error:  1.1395691798535431e-07
# v error:  4.208314038113071e-09
# m error:  4.214963193114416e-09

# %% [markdown]
# Once you have debugged your RMSProp and Adam implementations, run the following to train a pair of deep networks using these new update rules:

# %%
learning_rates = {'rmsprop': 1e-4, 'adam': 1e-3}
for update_rule in ['adam', 'rmsprop']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )
    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': learning_rates[update_rule]},
        verbose=True
    )
    solvers[update_rule] = solver
    solver.train()
    print()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"{update_rule}")

for ax in axes:
    ax.legend(loc='best', ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  adam
# (Iteration 1 / 200) loss: 2.563120
# (Epoch 0 / 5) train acc: 0.153000; val_acc: 0.149000
# (Iteration 11 / 200) loss: 2.072086
# (Iteration 21 / 200) loss: 1.847561
# (Iteration 31 / 200) loss: 1.808452
# (Epoch 1 / 5) train acc: 0.354000; val_acc: 0.331000
# (Iteration 41 / 200) loss: 1.895116
# (Iteration 51 / 200) loss: 1.854684
# (Iteration 61 / 200) loss: 1.505719
# (Iteration 71 / 200) loss: 1.624802
# (Epoch 2 / 5) train acc: 0.448000; val_acc: 0.338000
# (Iteration 81 / 200) loss: 1.751497
# (Iteration 91 / 200) loss: 1.657350
# (Iteration 101 / 200) loss: 1.553915
# (Iteration 111 / 200) loss: 1.390804
# (Epoch 3 / 5) train acc: 0.507000; val_acc: 0.371000
# (Iteration 121 / 200) loss: 1.428411
# (Iteration 131 / 200) loss: 1.456625
# (Iteration 141 / 200) loss: 1.569356
# (Iteration 151 / 200) loss: 1.462459
# (Epoch 4 / 5) train acc: 0.567000; val_acc: 0.374000
# (Iteration 161 / 200) loss: 1.323774
# (Iteration 171 / 200) loss: 1.147408
# (Iteration 181 / 200) loss: 1.190087
# (Iteration 191 / 200) loss: 1.234673
# (Epoch 5 / 5) train acc: 0.563000; val_acc: 0.373000
#
# Running with  rmsprop
# (Iteration 1 / 200) loss: 2.697234
# (Epoch 0 / 5) train acc: 0.135000; val_acc: 0.115000
# (Iteration 11 / 200) loss: 2.060316
# (Iteration 21 / 200) loss: 1.950593
# (Iteration 31 / 200) loss: 1.831267
# (Epoch 1 / 5) train acc: 0.348000; val_acc: 0.304000
# (Iteration 41 / 200) loss: 1.825785
# (Iteration 51 / 200) loss: 1.937715
# (Iteration 61 / 200) loss: 1.911134
# (Iteration 71 / 200) loss: 1.715865
# (Epoch 2 / 5) train acc: 0.421000; val_acc: 0.317000
# (Iteration 81 / 200) loss: 1.720962
# (Iteration 91 / 200) loss: 1.613130
# (Iteration 101 / 200) loss: 1.571659
# (Iteration 111 / 200) loss: 1.611386
# (Epoch 3 / 5) train acc: 0.471000; val_acc: 0.343000
# (Iteration 121 / 200) loss: 1.693972
# (Iteration 131 / 200) loss: 1.379943
# (Iteration 141 / 200) loss: 1.467681
# (Iteration 151 / 200) loss: 1.350323
# (Epoch 4 / 5) train acc: 0.520000; val_acc: 0.349000
# (Iteration 161 / 200) loss: 1.395957
# (Iteration 171 / 200) loss: 1.498545
# (Iteration 181 / 200) loss: 1.357810
# (Iteration 191 / 200) loss: 1.399339
# (Epoch 5 / 5) train acc: 0.558000; val_acc: 0.344000

# %% [markdown]
# ## Inline Question 2:
#
# AdaGrad, like Adam, is a per-parameter optimization method that uses the following update rule:
#
# ```
# cache += dw**2
# w += - learning_rate * dw / (np.sqrt(cache) + eps)
# ```
#
# John notices that when he was training a network with AdaGrad that the updates became very small, and that his network was learning slowly. Using your knowledge of the AdaGrad update rule, why do you think the updates would become very small? Would Adam have the same issue?
#
# ## AdaGrad 会把梯度平方一直累加到 cache 中，因此 cache 会越来越大，更新公式中的分母 sqrt(cache)+eps 也会越来越大，导致参数更新步长越来越小，训练后期容易变得很慢。Adam 通常不会有同样严重的问题，因为 Adam 对梯度和梯度平方使用的是指数滑动平均（会遗忘较早历史），而不是无限累加，所以有效学习率不会像 AdaGrad 那样持续衰减到很小。

# %% [markdown]
# # Train a Good Model!
# Train the best fully connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 50% accuracy on the validation set using a fully connected network.
#
# If you are careful it should be possible to get accuracies above 55%, but we don't require it for this part and won't assign extra credit for doing so. Later in the next assignment, we will ask you to train the best convolutional network that you can on CIFAR-10, and we would prefer that you spend your effort working on convolutional networks rather than fully connected networks.
#
# **Note:** In the next assignment, you will learn techniques like BatchNormalization and Dropout which can help you train powerful models.

# %%
best_model = None

################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# find batch/layer normalization and dropout useful. Store your best model in  #
# the best_model variable.                                                     #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****


# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****


# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 37
#      12 model = FullyConnectedNet(
#      13     [256, 256, 128, 128],
#      14     input_dim=3 * 32 * 32,
#    (...)     20     dtype=np.float32
#      21 )
#      23 solver = Solver(
#      24     model,
#      25     data,
#    (...)     34     verbose=True
#      35 )
# ---> 37 solver.train()
#      39 best_model = model
#      41 # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
#      42
#      43
#    (...)     46 #                              END OF YOUR CODE                                #
#      47 ################################################################################
#
# File ~\assignment1\cs231n\solver.py:263, in Solver.train(self)
#     260 num_iterations = self.num_epochs * iterations_per_epoch
#     262 for t in range(num_iterations):
# --> 263     self._step()
#     265     # Maybe print training loss
#     266     if self.verbose and t % self.print_every == 0:
#
# File ~\assignment1\cs231n\solver.py:181, in Solver._step(self)
#     178 y_batch = self.y_train[batch_mask]
#     180 # Compute loss and gradient
# --> 181 loss, grads = self.model.loss(X_batch, y_batch)
#     182 self.loss_history.append(loss)
#     184 # Perform a parameter update
#
# File ~\assignment1\cs231n\classifiers\fc_net.py:409, in FullyConnectedNet.loss(self, X, y)
#     407 for i in reversed(range(1,self.num_layers)):
#     408     if self.use_dropout:
# --> 409         dout = dropout_backward(dout, dropout_caches[i])
#     411     if self.normalization is None:
#     412         # cache format: (fc_cache, relu_cache)
#     413         fc_cache, relu_cache = caches[i]
#
# NameError: name 'dropout_caches' is not defined

# %% [markdown]
# # Test Your Model!
# Run your best model on the validation and test sets. You should achieve at least 50% accuracy on the validation set and the test set.

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
